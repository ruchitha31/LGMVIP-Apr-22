# %% [markdown]
# ### LetsGrowMoreVIP - Data Science Internship (May '22)

# %% [markdown]
# Beginner Level Task 2:Image to Pencil Sketch with Python

# %% [markdown]
# 1.Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("/content/dog.jpg")

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2917BCD450>

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2917B722D0>

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2917BDAC10>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2917CE1DD0>

# %%
cv2_imshow(img)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2917BE4990>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2917BE4B50>
